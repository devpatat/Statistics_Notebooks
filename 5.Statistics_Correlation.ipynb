# %%
import warnings 
warnings.simplefilter(action='ignore',category=FutureWarning)

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv("Loan_analysis.csv")

# %%
df.head()
# Out:
#    fico_score  loan_total  ...  default_rate  actual_default_rate
# 0         500        1188  ...      2.323350             0.461809
# 1         510        2825  ...      5.533458             1.099877
# 2         520        3291  ...      6.223678             1.237071
# 3         530        3621  ...      6.801591             1.351942
# 4         540        4029  ...      7.243800             1.439839
#
# [5 rows x 10 columns]

# %%
df.describe()
# Out:
#        fico_score    loan_total  ...  default_rate  actual_default_rate
# count   36.000000     36.000000  ...     36.000000            36.000000
# mean   675.000000   5972.888889  ...      2.777778             0.552135
# std    105.356538   4129.135079  ...      2.599778             0.516754
# min    500.000000     43.000000  ...      0.007019             0.001395
# 25%    587.500000   3750.000000  ...      0.162611             0.032322
# 50%    675.000000   4223.500000  ...      2.336219             0.464367
# 75%    762.500000   8361.750000  ...      4.844993             0.963032
# max    850.000000  14095.000000  ...      7.323350             1.455651
#
# [8 rows x 10 columns]

# %%
df.cov()
# Out:
#                         fico_score  ...  actual_default_rate
# fico_score            11100.000000  ...           -48.905770
# loan_total            37701.428571  ...          -342.075358
# default_total       -105159.142857  ...           574.188612
# dti                    -152.960152  ...             0.711320
# avg_loan_amnt         94841.853407  ...          -337.160173
# median_annual_inc    570027.788571  ...         -2397.803470
# avg_annual_inc       694964.177569  ...         -2837.122710
# int_rate               -249.339772  ...             1.092147
# default_rate           -246.043853  ...             1.343446
# actual_default_rate     -48.905770  ...             0.267035
#
# [10 rows x 10 columns]

# %%
df.corr()
# Out:
#                      fico_score  loan_total  ...  default_rate  actual_default_rate
# fico_score             1.000000    0.086664  ...     -0.898286            -0.898286
# loan_total             0.086664    1.000000  ...     -0.160317            -0.160317
# default_total         -0.898286   -0.160317  ...      1.000000             1.000000
# dti                   -0.907870    0.174854  ...      0.860772             0.860772
# avg_loan_amnt          0.708138   -0.420902  ...     -0.513253            -0.513253
# median_annual_inc      0.913955   -0.033137  ...     -0.783827            -0.783827
# avg_annual_inc         0.926910   -0.027632  ...     -0.771491            -0.771491
# int_rate              -0.962303    0.116939  ...      0.859368             0.859368
# default_rate          -0.898286   -0.160317  ...      1.000000             1.000000
# actual_default_rate   -0.898286   -0.160317  ...      1.000000             1.000000
#
# [10 rows x 10 columns]

# %%
#pearson shows relationship between linerally related value, spearman for non-parametric test. measures degree of association. evaluates the monotonic relationship btw cont and ordinal var.
#spearman doesnt have assumption on dist of data
df.corr(method='spearman')
# Out:
#                      fico_score  loan_total  ...  default_rate  actual_default_rate
# fico_score             1.000000    0.074131  ...     -0.933522            -0.933522
# loan_total             0.074131    1.000000  ...      0.043246             0.043246
# default_total         -0.933522    0.043246  ...      1.000000             1.000000
# dti                   -0.935135    0.015701  ...      0.970848             0.970848
# avg_loan_amnt          0.706564   -0.285199  ...     -0.640839            -0.640839
# median_annual_inc      0.953544    0.128028  ...     -0.876835            -0.876835
# avg_annual_inc         0.959331    0.097297  ...     -0.878435            -0.878435
# int_rate              -0.997426   -0.068726  ...      0.936354             0.936354
# default_rate          -0.933522    0.043246  ...      1.000000             1.000000
# actual_default_rate   -0.933522    0.043246  ...      1.000000             1.000000
#
# [10 rows x 10 columns]

# %%
sns.distplot(df['median_annual_inc'])

# %%
df[['fico_score','median_annual_inc']].corr('spearman')
# Out:
#                    fico_score  median_annual_inc
# fico_score           1.000000           0.953544
# median_annual_inc    0.953544           1.000000

# %%
sns.regplot(x='fico_score',y='median_annual_inc',data=df)

# %%
sns.regplot(x='fico_score',y='avg_annual_inc',data=df)

# %%
df[['fico_score','dti']].corr('spearman')
# Out:
#             fico_score       dti
# fico_score    1.000000 -0.935135
# dti          -0.935135  1.000000

# %%
sns.regplot(x='fico_score',y='dti',data=df)

# %%
df[['fico_score','int_rate']].corr('spearman')
# Out:
#             fico_score  int_rate
# fico_score    1.000000 -0.997426
# int_rate     -0.997426  1.000000

# %%
sns.regplot(x='fico_score',y='int_rate',data=df)

# %%
sns.distplot(df['int_rate'])

# %%
from scipy import stats
stats.probplot(df['int_rate'],dist='norm',plot=plt)
# Out:
# ((array([-2.07334886, -1.68217954, -1.44830429, -1.27437681, -1.13225357,
#          -1.00993636, -0.90112151, -0.80205412, -0.71029762, -0.62416759,
#          -0.54243995, -0.46418751, -0.38868208, -0.31533241, -0.24364313,
#          -0.17318609, -0.10357945, -0.03447167,  0.03447167,  0.10357945,
#           0.17318609,  0.24364313,  0.31533241,  0.38868208,  0.46418751,
#           0.54243995,  0.62416759,  0.71029762,  0.80205412,  0.90112151,
#           1.00993636,  1.13225357,  1.27437681,  1.44830429,  1.68217954,
#           2.07334886]),
#   array([ 7.78046512,  8.51682657,  8.71043991,  9.16660064,  9.55243581,
#           9.93851041, 10.17130271, 10.71445224, 10.93380161, 11.17743394,
#          11.47581685, 11.70816922, 12.01180393, 12.39100421, 12.80340524,
#          13.14978716, 13.60326723, 13.8964368 , 14.33353604, 14.3753678 ,
#          14.38378624, 14.54318352, 14.63224508, 14.87958103, 14.9314676 ,
# ...

# %%
df[['fico_score','loan_total']].corr('spearman')
# Out:
#             fico_score  loan_total
# fico_score    1.000000    0.074131
# loan_total    0.074131    1.000000

# %%
sns.regplot(x='fico_score',y='loan_total',data=df)
